# %%
# Import all the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.pipeline import Pipeline

# %%
# Load the feature engineered dataset

df = pd.read_csv('HDB_Resale_Prices_Features_Engineered.csv')
# Out:
# /var/folders/ts/ppg8j36j68n6_wr26q2fbv5c0000gn/T/ipykernel_65060/309347354.py:3: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('HDB_Resale_Prices_Features_Engineered.csv')

# %%
# Ensure all the values in 'postal_code' are strings

df['postal_code'] = df['postal_code'].astype(str)

# %%
# Checke null values and data types

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193875 entries, 0 to 193874
# Data columns (total 96 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   month                               193875 non-null  object
#  1   town                                193875 non-null  object
#  2   flat_type                           193875 non-null  object
#  3   block                               193875 non-null  object
#  4   street_name                         193875 non-null  object
#  5   floor_area_sqm                      193875 non-null  float64
#  6   flat_model                          193875 non-null  object
#  7   remaining_lease                     193875 non-null  object
#  8   resale_price                        193875 non-null  float64
#  9   year                                193875 non-null  int64
#  10  quarter                             193875 non-null  int64
#  11  storey_avg                          193875 non-null  float64
#  12  lease_age                           193875 non-null  int64
#  13  remaining_lease_years               193875 non-null  float64
#  14  postal_code                         193875 non-null  object
#  15  lat                                 193875 non-null  float64
#  16  lon                                 193875 non-null  float64
#  17  dist_to_nearest_mrt_km              193875 non-null  float64
#  18  nearest_mrt_name                    193875 non-null  object
#  19  within_500m_mrt                     193875 non-null  int64
#  20  within_1km_mrt                      193875 non-null  int64
#  21  dist_to_cbd_km                      193875 non-null  float64
#  22  pt_time_to_cbd_min                  193875 non-null  float64
#  23  pt_time_to_cbd_min_adj              193875 non-null  float64
#  24  drive_time_to_cbd_min               193875 non-null  float64
#  25  dist_to_nearest_top_primary_km      193875 non-null  float64
#  26  nearest_top_primary_name            193875 non-null  object
#  27  within_1km_top_primary              193875 non-null  int64
#  28  dist_to_nearest_top_primary_km.1    193875 non-null  float64
#  29  nearest_top_primary_name.1          193875 non-null  object
#  30  within_1km_top_primary.1            193875 non-null  int64
#  31  dist_to_nearest_top_secondary_km    193875 non-null  float64
#  32  nearest_top_secondary_name          193875 non-null  object
#  33  within_2km_top_secondary            193875 non-null  int64
#  34  dist_to_nearest_jc_km               193875 non-null  float64
#  35  nearest_jc_name                     193875 non-null  object
#  36  within_3km_jc                       193875 non-null  int64
#  37  dist_to_nearest_poly_km             193875 non-null  float64
#  38  nearest_poly_name                   193875 non-null  object
#  39  within_5km_poly                     193875 non-null  int64
#  40  estate_age_bucket                   193875 non-null  object
#  41  lease_commence_year                 193875 non-null  int64
#  42  is_mature_estate                    193875 non-null  int64
#  43  is_very_old_estate                  193875 non-null  int64
#  44  avg_floor                           193875 non-null  float64
#  45  floor_category                      193875 non-null  object
#  46  floor_tier                          193875 non-null  int64
#  47  floor_premium_factor                193875 non-null  float64
#  48  is_mrt_noise_zone                   193875 non-null  int64
#  49  is_mrt_influence_zone               193875 non-null  int64
#  50  is_high_mrt_noise_low_floor         193875 non-null  int64
#  51  cbd_noise_band                      193875 non-null  object
#  52  noise_score                         193875 non-null  int64
#  53  noise_category                      193875 non-null  object
#  54  block_year_txn                      193875 non-null  int64
#  55  block_total_txn                     193875 non-null  int64
#  56  town_year_txn                       193875 non-null  int64
#  57  town_total_txn                      193875 non-null  int64
#  58  block_share_of_town_year            193875 non-null  float64
#  59  block_share_of_town_year_pct        193875 non-null  float64
#  60  block_year_rank_in_town             193875 non-null  int64
#  61  block_cum_txn                       193875 non-null  int64
#  62  town_cum_txn                        193875 non-null  int64
#  63  nearest_mall_name                   193875 non-null  object
#  64  dist_to_nearest_mall_km             193875 non-null  float64
#  65  within_500m_mall                    193875 non-null  int64
#  66  within_1km_mall                     193875 non-null  int64
#  67  within_2km_mall                     193875 non-null  int64
#  68  nearest_bus_interchange_name        193875 non-null  object
#  69  dist_to_nearest_bus_interchange_km  193875 non-null  float64
#  70  within_500m_bus_interchange         193875 non-null  int64
#  71  within_1km_bus_interchange          193875 non-null  int64
#  72  within_2km_bus_interchange          193875 non-null  int64
#  73  nearest_hawker_name                 193875 non-null  object
#  74  dist_to_nearest_hawker_km           193875 non-null  float64
#  75  within_500m_hawker                  193875 non-null  int64
#  76  within_1km_hawker                   193875 non-null  int64
#  77  within_2km_hawker                   193875 non-null  int64
#  78  nearest_hospital_name               193875 non-null  object
#  79  dist_to_nearest_hospital_km         193875 non-null  float64
#  80  within_1km_hospital                 193875 non-null  int64
#  81  within_2km_hospital                 193875 non-null  int64
#  82  within_5km_hospital                 193875 non-null  int64
#  83  nearest_supermarket_name            193875 non-null  object
#  84  nearest_supermarket_chain           193875 non-null  object
#  85  dist_to_nearest_supermarket_km      193875 non-null  float64
#  86  within_500m_supermarket             193875 non-null  int64
#  87  within_1km_supermarket              193875 non-null  int64
#  88  within_2km_supermarket              193875 non-null  int64
#  89  malls_within_1km                    193875 non-null  int64
#  90  hawkers_within_1km                  193875 non-null  int64
#  91  bus_interchanges_within_1km         193875 non-null  int64
#  92  hospitals_within_1km                193875 non-null  int64
#  93  supermarkets_within_1km             193875 non-null  int64
#  94  total_amenities_within_1km          193875 non-null  int64
#  95  amenity_cluster_category            193875 non-null  object
# dtypes: float64(25), int64(46), object(25)
# memory usage: 142.0+ MB
# None

# %%
# Identify numeric and categorical features

numeric_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if 'resale_price' in numeric_features:
    numeric_features.remove('resale_price')
    
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
# Split the dataset into training and testing sets

x = df.drop(['resale_price'],axis=1)
y = df['resale_price']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

print(len(x_train),len(x_test))
# Out:
# 155100 38775

# %%
# Define a custom RMSE function

def rmse(y_true,y_pred):
    return round(np.sqrt(mean_squared_error(y_true,y_pred)),2)

# Function to train model and display R2 and RMSE

def results(train_x,train_y,test_x,test_y,model,model_name):
    model.fit(train_x,train_y)
    y_pred = model.predict(test_x)
    model_r2 = round(r2_score(test_y,y_pred),2)
    model_rmse = round(rmse(test_y,y_pred),0)

    print(f"{model_name} R²:   {model_r2}")
    print(f"{model_name} RMSE: {model_rmse}")

    return model_r2, model_rmse

# %%
# Preprocessor for the ML pipeline

preprocessor = ColumnTransformer([
    ('num',StandardScaler(),numeric_features),
    ('cat',OneHotEncoder(handle_unknown='ignore'),categorical_features)
])

# %%
# Linear Regression Model

linreg_model = Pipeline([
    ('preprocessor',preprocessor),
    ('regressor',LinearRegression())
])

# Evaluate Linear Regression Model

linreg_r2,linreg_rmse = results(x_train,y_train,x_test,y_test,linreg_model,'Linear Regression')
# Out:
# Linear Regression R²:   0.96
# Linear Regression RMSE: 34593.0

# %%
rf_model = Pipeline([
    ('preprocessor',preprocessor),
    ('regressor',RandomForestRegressor(
        n_estimators=400,
        max_depth=None,
        min_samples_split=5,
        min_samples_leaf=2,
        random_state=42,
        n_jobs=-1,
        verbose=0
    ))
])

# Evaluate Random Forest Model

rf_r2,rf_rmse = results(x_train,y_train,x_test,y_test,rf_model,'Random Forest')
# Out:
# Random Forest R²:   0.97
# Random Forest RMSE: 27833.0

# %%
# DataFrame to compare model performance

results = pd.DataFrame({
    'Model': ['Linear Regression','Random Forest'],
    'R2': [linreg_r2,rf_r2],
    'RMSE': [linreg_rmse,rf_rmse]
})

# Display the model results

print(results)
# Out:
#                Model    R2     RMSE
# 0  Linear Regression  0.96  34593.0
# 1      Random Forest  0.97  27833.0

# %%
# Since Random Forest performed better, we will analyze its feature importances

# Extract categorical feature names after one-hot encoding

ohe = rf_model.named_steps['preprocessor'].named_transformers_['cat']
ohe_feature_names = ohe.get_feature_names_out(categorical_features)

# Combine numeric and categorical feature names

all_feature_names = np.concatenate([numeric_features,ohe_feature_names])

# Extract feature importances from the Random Forest model

rf_reg = rf_model.named_steps['regressor']
importances = rf_reg.feature_importances_

# Create a DataFrame for feature importances

feature_df = pd.DataFrame({
    'feature':all_feature_names,
    'importance':importances
}).sort_values(by='importance',ascending=False)

# %%
print(feature_df)
# Out:
#                       feature  importance
# 0              floor_area_sqm    0.425893
# 13     pt_time_to_cbd_min_adj    0.166683
# 1                        year    0.131115
# 25        lease_commence_year    0.093945
# 12         pt_time_to_cbd_min    0.011263
# ...                       ...         ...
# 7937       postal_code_530695    0.000000
# 7943       postal_code_530702    0.000000
# 12756      postal_code_760361    0.000000
# 7954       postal_code_530804    0.000000
# 12818      postal_code_760602    0.000000
#
# [14450 rows x 2 columns]

# %%
feature_df.to_csv("feature_importances.csv", index=False)
