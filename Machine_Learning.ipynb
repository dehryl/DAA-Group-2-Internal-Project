# %%
# Import all the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.pipeline import Pipeline

# %%
# Load the feature engineered dataset

df = pd.read_csv('HDB_Resale_Prices_Features_Engineered.csv')
# Out:
# /var/folders/ts/ppg8j36j68n6_wr26q2fbv5c0000gn/T/ipykernel_8159/309347354.py:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('HDB_Resale_Prices_Features_Engineered.csv')

# %%
# Ensure all the values in 'postal_code' are strings

df['postal_code'] = df['postal_code'].astype(str)

# %%
# Checke null values and data types

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194170 entries, 0 to 194169
# Data columns (total 86 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   month                               194170 non-null  object
#  1   town                                194170 non-null  object
#  2   flat_type                           194170 non-null  object
#  3   block                               194170 non-null  object
#  4   street_name                         194170 non-null  object
#  5   storey_range                        194170 non-null  object
#  6   floor_area_sqm                      194170 non-null  float64
#  7   flat_model                          194170 non-null  object
#  8   lease_commence_date                 194170 non-null  int64
#  9   remaining_lease                     194170 non-null  object
#  10  resale_price                        194170 non-null  float64
#  11  postal_code                         194170 non-null  object
#  12  lat_x                               194170 non-null  float64
#  13  lon_x                               194170 non-null  float64
#  14  lat_y                               194170 non-null  float64
#  15  lon_y                               194170 non-null  float64
#  16  lat                                 194170 non-null  float64
#  17  lon                                 194170 non-null  float64
#  18  dist_to_nearest_mrt_km              194170 non-null  float64
#  19  nearest_mrt_name                    194170 non-null  object
#  20  within_500m_mrt                     194170 non-null  int64
#  21  within_1km_mrt                      194170 non-null  int64
#  22  dist_to_cbd_km                      194170 non-null  float64
#  23  pt_time_to_cbd_min                  194170 non-null  float64
#  24  pt_time_to_cbd_min_adj              194170 non-null  float64
#  25  drive_time_to_cbd_min               194170 non-null  float64
#  26  dist_to_nearest_top_primary_km      194170 non-null  float64
#  27  nearest_top_primary_name            194170 non-null  object
#  28  within_1km_top_primary              194170 non-null  int64
#  29  dist_to_nearest_top_secondary_km    194170 non-null  float64
#  30  nearest_top_secondary_name          194170 non-null  object
#  31  within_2km_top_secondary            194170 non-null  int64
#  32  dist_to_nearest_jc_km               194170 non-null  float64
#  33  nearest_jc_name                     194170 non-null  object
#  34  within_3km_jc                       194170 non-null  int64
#  35  dist_to_nearest_poly_km             194170 non-null  float64
#  36  nearest_poly_name                   194170 non-null  object
#  37  within_5km_poly                     194170 non-null  int64
#  38  remaining_lease_years               194170 non-null  float64
#  39  lease_commence_year                 194170 non-null  int64
#  40  lease_age_2025                      194170 non-null  int64
#  41  estate_age_bucket                   194170 non-null  object
#  42  is_mature_estate                    194170 non-null  int64
#  43  is_very_old_estate                  194170 non-null  int64
#  44  min_floor                           194170 non-null  float64
#  45  max_floor                           194170 non-null  float64
#  46  avg_floor                           194170 non-null  float64
#  47  floor_category                      194170 non-null  object
#  48  floor_tier                          194170 non-null  int64
#  49  floor_premium_factor                194170 non-null  float64
#  50  is_mrt_noise_zone                   194170 non-null  int64
#  51  is_mrt_influence_zone               194170 non-null  int64
#  52  is_high_mrt_noise_low_floor         194170 non-null  int64
#  53  cbd_noise_band                      194170 non-null  object
#  54  noise_score                         194170 non-null  int64
#  55  noise_category                      194170 non-null  object
#  56  year                                194170 non-null  int64
#  57  block_year_txn                      194170 non-null  int64
#  58  block_total_txn                     194170 non-null  int64
#  59  town_year_txn                       194170 non-null  int64
#  60  town_total_txn                      194170 non-null  int64
#  61  block_share_of_town_year            194170 non-null  float64
#  62  block_share_of_town_year_pct        194170 non-null  float64
#  63  block_year_rank_in_town             194170 non-null  int64
#  64  block_cum_txn                       194170 non-null  int64
#  65  town_cum_txn                        194170 non-null  int64
#  66  nearest_mall_name                   194170 non-null  object
#  67  dist_to_nearest_mall_km             194170 non-null  float64
#  68  within_500m_mall                    194170 non-null  int64
#  69  within_1km_mall                     194170 non-null  int64
#  70  within_2km_mall                     194170 non-null  int64
#  71  nearest_bus_interchange_name        194170 non-null  object
#  72  dist_to_nearest_bus_interchange_km  194170 non-null  float64
#  73  within_500m_bus_interchange         194170 non-null  int64
#  74  within_1km_bus_interchange          194170 non-null  int64
#  75  within_2km_bus_interchange          194170 non-null  int64
#  76  nearest_hawker_name                 194170 non-null  object
#  77  dist_to_nearest_hawker_km           194170 non-null  float64
#  78  within_500m_hawker                  194170 non-null  int64
#  79  within_1km_hawker                   194170 non-null  int64
#  80  within_2km_hawker                   194170 non-null  int64
#  81  malls_within_1km                    194170 non-null  int64
#  82  hawkers_within_1km                  194170 non-null  int64
#  83  bus_interchanges_within_1km         194170 non-null  int64
#  84  total_amenities_within_1km          194170 non-null  int64
#  85  amenity_cluster_category            194170 non-null  object
# dtypes: float64(27), int64(37), object(22)
# memory usage: 127.4+ MB
# None

# %%
# Identify numeric and categorical features

numeric_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if 'resale_price' in numeric_features:
    numeric_features.remove('resale_price')
    
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
# Split the dataset into training and testing sets

x = df.drop(['resale_price'],axis=1)
y = df['resale_price']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

print(len(x_train),len(x_test))
# Out:
# 155336 38834

# %%
# Define a custom RMSE function

def rmse(y_true,y_pred):
    return round(np.sqrt(mean_squared_error(y_true,y_pred)),2)

# Function to train model and display R2 and RMSE

def results(x_train,y_train,x_test,y_test,model,model_name):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    model_r2 = round(r2_score(y_test,y_pred),2)
    model_rmse = round(rmse(y_test,y_pred),0)

    print(f"{model_name} R²:   {model_r2}")
    print(f"{model_name} RMSE: {model_rmse}")

    return model_r2, model_rmse

# %%
# Preprocessor for the ML pipeline

preprocessor = ColumnTransformer([
    ('num',StandardScaler(),numeric_features),
    ('cat',OneHotEncoder(handle_unknown='ignore'),categorical_features)
])

# %%
# Linear Regression Model

linreg_model = Pipeline([
    ('preprocessor',preprocessor),
    ('regressor',LinearRegression())
])

# Evaluate Linear Regression Model

linreg_r2,linreg_rmse = results(x_train,y_train,x_test,y_test,linreg_model,'Linear Regression')
# Out:
# Linear Regression R²:   0.96
# Linear Regression RMSE: 34802.0

# %%
# Random Forest Model

rf_model = Pipeline([
    ('preprocessor',preprocessor),
    ('regressor',RandomForestRegressor(
        n_estimators=200,
        max_depth=None,
        min_samples_split=5,
        min_samples_leaf=2,
        random_state=42,
        n_jobs=-1,
        verbose=0
    ))
])

# Evaluate Random Forest Model

rf_r2,rf_rmse = results(x_train,y_train,x_test,y_test,rf_model,'Random Forest')
# Out:
# The kernel failed to start as the Python Environment 'Python 3.14.0' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# DataFrame to compare model performance

results = pd.DataFrame({
    'Model': ['Linear Regression','Random Forest'],
    'R2': [linreg_r2,rf_r2],
    'RMSE': [linreg_rmse,rf_rmse]
})

# Display the model results

print(results)
# Out:
#                Model    R2     RMSE
# 0  Linear Regression  0.96  34802.0
# 1      Random Forest  0.98  27633.0

# %%
# Since Random Forest performed better, we will analyze its feature importances

# Extract categorical feature names after one-hot encoding

ohe = rf_model.named_steps['preprocessor'].named_transformers_['cat']
ohe_feature_names = ohe.get_feature_names_out(categorical_features)

# Combine numeric and categorical feature names

all_feature_names = np.concatenate([numeric_features,ohe_feature_names])

# Extract feature importances from the Random Forest model

rf_reg = rf_model.named_steps['regressor']
importances = rf_reg.feature_importances_

# Create a DataFrame for feature importances

feature_df = pd.DataFrame({
    'feature':all_feature_names,
    'importance':importances
}).sort_values(by='importance',ascending=False)

# %%
feature_df.to_csv("feature_importances.csv", index=False)
